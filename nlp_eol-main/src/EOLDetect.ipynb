# %% [markdown]
# <a href="https://colab.research.google.com/github/alokrep/npl_eol/blob/main/src/EOLDetect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import re
import nltk
import sys
import os
from sklearn.feature_extraction.text import CountVectorizer
from numpy import dot
from numpy.linalg import norm
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Read in data and preprocess

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filepath = '/content/drive/MyDrive/Kids/Neal/DataScience/eol'
sys.path.append(filepath)
os.chdir(filepath)
sys.path.append(filepath)
# pylint: disable=wildcard-import
from eol_utils import *

# %%
# !pip install matplotlib-venn
# Out:
# Requirement already satisfied: matplotlib-venn in /usr/local/lib/python3.10/dist-packages (0.11.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (1.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)

# %%
# !pip install matplotlib-venn
# Out:
# Requirement already satisfied: matplotlib-venn in /usr/local/lib/python3.10/dist-packages (0.11.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (1.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)

# %%
# !pip install matplotlib-venn
# Out:
# Requirement already satisfied: matplotlib-venn in /usr/local/lib/python3.10/dist-packages (0.11.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (1.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)

# %%
# !pip install matplotlib-venn
# Out:
# Requirement already satisfied: matplotlib-venn in /usr/local/lib/python3.10/dist-packages (0.11.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (1.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)

# %%
# !pip install matplotlib-venn
# Out:
# Requirement already satisfied: matplotlib-venn in /usr/local/lib/python3.10/dist-packages (0.11.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (1.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)

# %%
# !pip install matplotlib-venn
# Out:
# Requirement already satisfied: matplotlib-venn in /usr/local/lib/python3.10/dist-packages (0.11.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from matplotlib-venn) (1.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matplotlib-venn) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
from eol_config import eol_path, pickle_path, train_path, train_file, ngram_range

# %%
data = pd.read_csv('eol_train_data_v10.csv')

# %%
data.drop_duplicates(subset='plugin_id', inplace=True)

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
data['title'] = data['title'].replace(np.nan, '')
data['description'] = data['description'].replace(np.nan, '')
data['clean_desc'] = data['title'].values + ' ' + data['description'].values
data['clean_desc'] = data['clean_desc'].apply(pre_process)
# Out:
# /content/drive/MyDrive/Kids/Neal/DataScience/eol/eol_utils.py:24: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = Soup(html_str, features="html.parser")

# %%
data['clean_desc'] = data['clean_desc'].apply(lambda x: re.sub(" eol ", " ", x))
data['clean_desc'] = data['clean_desc'].apply(lambda x: re.sub("^eol ", "", x))
data['clean_desc'] = data['clean_desc'].apply(lambda x: re.sub(" obsolete ", " ", x))
data['clean_desc'] = data['clean_desc'].apply(lambda x: re.sub("^obsolete ", "", x))

# %%
np.unique(data['is_eol'], return_counts = True)
# Out:
# (array([False,  True]), array([685, 836]))

# %% [markdown]
# ## Random forest over bag of words

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
data_train, data_test = train_test_split(data, test_size=0.2, random_state=7)

# %%
results = pd.DataFrame({"gram_size":[], "no_of_features":[], "accuracy":[]})
for i in range(1,6):
  bow_clean_desc = CountVectorizer(ngram_range=(i,i))
  X_train = bow_clean_desc.fit_transform(data_train['clean_desc']).toarray()
  bow_features = bow_clean_desc.get_feature_names_out()
  X_test = bow_clean_desc.transform(data_test['clean_desc']).toarray()
  rf = RandomForestClassifier()
  rf = rf.fit(X_train, data_train['is_eol'].astype(int))
  y_pred = rf.predict(X_test)
  result = [i, len(bow_features), accuracy_score(data_test['is_eol'].astype(int), y_pred)]
  results.loc[len(results)] = result
results.round(2)
# Out:
#    gram_size  no_of_features  accuracy
# 0        1.0          5145.0      0.99
# 1        2.0         25979.0      0.98
# 2        3.0         34230.0      0.93
# 3        4.0         37719.0      0.89
# 4        5.0         39464.0      0.87

# %%
bow_clean_desc = CountVectorizer()
X_train = bow_clean_desc.fit_transform(data_train['clean_desc']).toarray()
bow_features = bow_clean_desc.get_feature_names_out()
X_test = bow_clean_desc.transform(data_test['clean_desc']).toarray()
rf = RandomForestClassifier()
rf = rf.fit(X_train, data_train['is_eol'].astype(int))
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
cm = confusion_matrix(data_test['is_eol'].astype(int), y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["not_eol", "eol"])
disp.plot(cmap='Oranges');

# %% [markdown]
# ## Old Version

# %%
eol = data[data['is_eol'] == True ]

# %%
not_eol = data[data['is_eol'] == False ]

# %%
eol
# Out:
#          plugin_id scanner                                              title  \
# 16    QUALYS105138  QUALYS  EOL/Obsolete Hardware: Juniper NetScreen-5GT D...
# 18    QUALYS105337  QUALYS  EOL/Obsolete Software: Microsoft Office 2000 S...
# 19    QUALYS105338  QUALYS  EOL/Obsolete Operating System: Microsoft Windo...
# 20    QUALYS105339  QUALYS  EOL/Obsolete Operating System: Microsoft Windo...
# 21    QUALYS105340  QUALYS  EOL/Obsolete Operating System: Microsoft Windo...
# ...            ...     ...                                                ...
# 1519         27587  NESSUS  Debian DSA-1396-1 : iceweasel - several vulner...
# 1520         27630  NESSUS  Debian DSA-1401-1 : iceape - several vulnerabi...
# 1521         29259  NESSUS  Debian DSA-1424-1 : iceweasel - several vulner...
# 1522         59108  NESSUS  Mobipocket Reader CHM File Handling Remote Ove...
# 1523         59661  NESSUS     Fedora 15 : kernel-2.6.43.8-1.fc15 (2012-8931)
#
#                                             description plugin_type  is_eol  \
# 16    juniper ended support for netscreen-5gt on dec...         NaN    True
# 18    microsoft office 2000 service pack 3 has been ...         NaN    True
# 19    the host is running windows vista with no serv...         NaN    True
# 20    the host is running windows server 2003 with n...         NaN    True
# 21    the host is running windows server 2003 with s...         NaN    True
# ...                                                 ...         ...     ...
# 1519  Several remote vulnerabilities have been disco...         NaN    True
# 1520  Several remote vulnerabilities have been disco...         NaN    True
# 1521  Several remote vulnerabilities have been disco...         NaN    True
# 1522  All versions of Mobipocket Reader are potentia...         NaN    True
# 1523  Update to Linux 2.6.43.8 (3.3.8).\n\nDisabled ...         NaN    True
#
#                                              clean_desc
# 16    hardware juniper netscreen gt detect juniper e...
# 18    software vendor office service pack sp detect ...
# 19    operate system vendor windows vista detect hos...
# 20    operate system vendor windows server detect ho...
# 21    operate system vendor windows server service p...
# ...                                                 ...
# 1519  debian dsa iceweasel several vulnerability sev...
# 1520  debian dsa iceape several vulnerability severa...
# 1521  debian dsa iceweasel several vulnerability sev...
# 1522  mobipocket reader chm file handle remote overf...
# 1523  vendor kernel fc update linux disable bit nx e...
#
# [836 rows x 7 columns]

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
# !python -m spacy download en_core_web_md
import en_core_web_md

text_to_nlp = en_core_web_md.load() # loading in the model
# Out:
# 2023-11-27 01:14:20.368370: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-27 01:14:20.368429: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-27 01:14:20.368478: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-27 01:14:21.521577: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-md==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.6.0/en_core_web_md-3.6.0-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-md==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.1.3)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
def tokenize_vecs(text):
    clean_tokens = []
    for token in text_to_nlp(text):
        if (not token.is_stop) & (token.lemma_ != '-PRON-') & (not token.is_punct):
          # -PRON- is a special all inclusive "lemma" spaCy uses for any pronoun, we want to exclude these
            clean_tokens.append(token)
    return np.array(clean_tokens)

# %%
def sum_and_avg_vectors(column):
  '''
    Returns the average of the embedding vectors
  '''
  X_word2vec = []
  for text in column:
    title = tokenize_vecs(text) # returns cleaned list of spacy tokens
    title_vec = [0]*300
    for word in title:
      title_vec += word.vector
    if np.sum(title_vec) > 0:
      title_vec = title_vec / len(title)
    X_word2vec.append(title_vec)

  return np.array(X_word2vec)

# %%
data
# Out:
#          plugin_id scanner                                              title  \
# 0     QUALYS100003  QUALYS  Microsoft Internet Explorer Cumulative Securit...
# 1     QUALYS100031  QUALYS  Microsoft Internet Explorer window() Code Exec...
# 2     QUALYS100046  QUALYS  Microsoft Internet Explorer Cumulative Securit...
# 3     QUALYS100047  QUALYS  Cumulative Security Update for Internet Explor...
# 4     QUALYS100050  QUALYS  Cumulative Security Update for Internet Explor...
# ...            ...     ...                                                ...
# 1521         29259  NESSUS  Debian DSA-1424-1 : iceweasel - several vulner...
# 1522         59108  NESSUS  Mobipocket Reader CHM File Handling Remote Ove...
# 1523         59661  NESSUS     Fedora 15 : kernel-2.6.43.8-1.fc15 (2012-8931)
# 1524         78008  NESSUS        RHEL 4 / 5 / 6 : JBoss EAP (RHSA-2014:1321)
# 1525         87194  NESSUS                RHEL 6 : JBoss EAP (RHSA-2015:2542)
#
#                                             description plugin_type  is_eol  \
# 0     the cumulative security update for microsoft i...         NaN   False
# 1     a critical vulnerability has been identified i...         NaN   False
# 2     multiple vulnerabilities exist in internet exp...         NaN   False
# 3     multiple vulnerabilities exist in internet exp...         NaN   False
# 4     a remote code execution vulnerability exists i...         NaN   False
# ...                                                 ...         ...     ...
# 1521  Several remote vulnerabilities have been disco...         NaN    True
# 1522  All versions of Mobipocket Reader are potentia...         NaN    True
# 1523  Update to Linux 2.6.43.8 (3.3.8).\n\nDisabled ...         NaN    True
# 1524  Updated packages for Red Hat JBoss Enterprise ...         NaN   False
# 1525  Updated jboss-ec2-eap packages that fix two se...         NaN   False
#
#                                              clean_desc
# 0     vendor internet explorer cumulative security u...
# 1     vendor internet explorer code execution vulner...
# 2     vendor internet explorer cumulative security u...
# 3     cumulative security update internet explorer m...
# 4     cumulative security update internet explorer m...
# ...                                                 ...
# 1521  debian dsa iceweasel several vulnerability sev...
# 1522  mobipocket reader chm file handle remote overf...
# 1523  vendor kernel fc update linux disable bit nx e...
# 1524  rhel jboss eap rhsa update package red hat jbo...
# 1525  rhel jboss eap rhsa update jboss ec eap packag...
#
# [1521 rows x 7 columns]

# %%
bow_title = CountVectorizer()
titles = bow_title.fit_transform(data['title'].astype(str)).toarray()
eol_titles = np.sum(bow_title.transform(eol['title'].astype(str)).toarray(), axis=0)
not_eol_titles = np.sum(bow_title.transform(not_eol['title'].astype(str)).toarray(), axis=0)
bow_descriptions = CountVectorizer()
descriptions = bow_descriptions.fit_transform(data['description'].astype(str)).toarray()
eol_descriptions = np.sum(bow_descriptions.transform(eol['description'].astype(str)).toarray(), axis=0)
not_eol_descriptions = np.sum(bow_descriptions.transform(not_eol['description'].astype(str)).toarray(), axis=0)

# %%
bow_clean_desc = CountVectorizer(ngram_range=(5,5))
clean_desc = bow_clean_desc.fit_transform(data['clean_desc']).toarray()
eol_clean_desc = np.sum(bow_clean_desc.transform(eol['clean_desc'].astype(str)).toarray(), axis=0)
not_eol_clean_desc = np.sum(bow_clean_desc.transform(not_eol['clean_desc'].astype(str)).toarray(), axis=0)

# %%
bow_features = bow_clean_desc.get_feature_names_out()

# %%
len(bow_features)
# Out:
# 46136

# %%
w2v_eol_titles = np.sum(sum_and_avg_vectors(eol['title'].astype(str)), axis = 0)
w2v_not_eol_titles = np.sum(sum_and_avg_vectors(not_eol['title'].astype(str)), axis = 0)
w2v_eol_descriptions = np.sum(sum_and_avg_vectors(eol['description'].astype(str)), axis= 0)
w2v_not_eol_descriptions = np.sum(sum_and_avg_vectors(not_eol['description'].astype(str)), axis = 0)

# %%
w2v_eol = np.sum(sum_and_avg_vectors(eol['clean_desc'].astype(str)), axis = 0)
w2v_not_eol = np.sum(sum_and_avg_vectors(not_eol['clean_desc'].astype(str)), axis = 0)
w2v_all = sum_and_avg_vectors(data['clean_desc'].astype(str))

# %%
def eol_predict(vectors, eol_vec, not_eol_vec):
  predictions = []
  for vector in vectors:
    not_eol_score = dot(vector, not_eol_vec.T)
    eol_score = dot(vector, eol_vec.T)
    if eol_score > not_eol_score:
      predictions.append(1)
    else:
      predictions.append(0)
  return predictions

# %%
predictions = eol_predict(titles, eol_titles, not_eol_titles)
accuracy_score(data['is_eol'].astype(int), predictions)
# Out:
# 0.9066403681788298

# %%
results = pd.DataFrame({"gram_size":[], "no_of_features":[], "accuracy":[]})
for i in range(1,6):
  bow_clean_desc = CountVectorizer(ngram_range=(i,i))
  clean_desc = bow_clean_desc.fit_transform(data['clean_desc']).toarray()
  bow_features = bow_clean_desc.get_feature_names_out()
  eol_clean_desc = np.sum(bow_clean_desc.transform(eol['clean_desc'].astype(str)).toarray(), axis=0)
  not_eol_clean_desc = np.sum(bow_clean_desc.transform(not_eol['clean_desc'].astype(str)).toarray(), axis=0)
  predictions = eol_predict(clean_desc, eol_clean_desc, not_eol_clean_desc)
  result = [i, len(bow_features), accuracy_score(data['is_eol'].astype(int), predictions)]
  results.loc[len(results)] = result
results.round(2)
# Out:
#    gram_size  no_of_features  accuracy
# 0        1.0          5580.0      0.67
# 1        2.0         29842.0      0.92
# 2        3.0         39812.0      0.97
# 3        4.0         44001.0      0.99
# 4        5.0         46136.0      1.00

# %%
predictions = eol_predict(w2v_all, w2v_eol, w2v_not_eol)
accuracy_score(data['is_eol'].astype(int), predictions)
# Out:
# 0.5496383957922419

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
cm = confusion_matrix(data['is_eol'].astype(int), predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["not_eol", "eol"])
disp.plot(cmap='Oranges');

# %%
data['predictions'] = predictions

# %%
data
# Out:
#          plugin_id scanner                                              title  \
# 0     QUALYS100003  QUALYS  Microsoft Internet Explorer Cumulative Securit...
# 1     QUALYS100031  QUALYS  Microsoft Internet Explorer window() Code Exec...
# 2     QUALYS100046  QUALYS  Microsoft Internet Explorer Cumulative Securit...
# 3     QUALYS100047  QUALYS  Cumulative Security Update for Internet Explor...
# 4     QUALYS100050  QUALYS  Cumulative Security Update for Internet Explor...
# ...            ...     ...                                                ...
# 1521         29259  NESSUS  Debian DSA-1424-1 : iceweasel - several vulner...
# 1522         59108  NESSUS  Mobipocket Reader CHM File Handling Remote Ove...
# 1523         59661  NESSUS     Fedora 15 : kernel-2.6.43.8-1.fc15 (2012-8931)
# 1524         78008  NESSUS        RHEL 4 / 5 / 6 : JBoss EAP (RHSA-2014:1321)
# 1525         87194  NESSUS                RHEL 6 : JBoss EAP (RHSA-2015:2542)
#
#                                             description plugin_type  is_eol  \
# 0     the cumulative security update for microsoft i...         NaN   False
# 1     a critical vulnerability has been identified i...         NaN   False
# 2     multiple vulnerabilities exist in internet exp...         NaN   False
# 3     multiple vulnerabilities exist in internet exp...         NaN   False
# 4     a remote code execution vulnerability exists i...         NaN   False
# ...                                                 ...         ...     ...
# 1521  Several remote vulnerabilities have been disco...         NaN    True
# 1522  All versions of Mobipocket Reader are potentia...         NaN    True
# 1523  Update to Linux 2.6.43.8 (3.3.8).\n\nDisabled ...         NaN    True
# 1524  Updated packages for Red Hat JBoss Enterprise ...         NaN   False
# 1525  Updated jboss-ec2-eap packages that fix two se...         NaN   False
#
#                                              clean_desc  predictions
# 0     vendor internet explorer cumulative security u...            1
# 1     vendor internet explorer code execution vulner...            1
# 2     vendor internet explorer cumulative security u...            1
# 3     cumulative security update internet explorer m...            1
# 4     cumulative security update internet explorer m...            1
# ...                                                 ...          ...
# 1521  debian dsa iceweasel several vulnerability sev...            1
# 1522  mobipocket reader chm file handle remote overf...            1
# 1523  vendor kernel fc update linux disable bit nx e...            1
# 1524  rhel jboss eap rhsa update package red hat jbo...            1
# 1525  rhel jboss eap rhsa update jboss ec eap packag...            1
#
# [1521 rows x 8 columns]

# %%
data[np.logical_and(data['is_eol'] == True, data['predictions'] == 0)]
# Out:
# Empty DataFrame
# Columns: [plugin_id, scanner, title, description, plugin_type, is_eol, clean_desc, predictions]
# Index: []

# %%
data[np.logical_and(data['is_eol'] == False, data['predictions'] == 1)]
# Out:
#                                               plugin_id  scanner  \
# 0                                          QUALYS100003   QUALYS
# 1                                          QUALYS100031   QUALYS
# 2                                          QUALYS100046   QUALYS
# 3                                          QUALYS100047   QUALYS
# 4                                          QUALYS100050   QUALYS
# ...                                                 ...      ...
# 1454  SERVICEPACK-RIGHTS-MGMT-SERVICES-CLIENT-SP2-IT...  NEXPOSE
# 1455  9B329198F37D3100957D95C62B0391F2585D6A30398EA0...   NESSUS
# 1456  A46995E4E058C68B706D9AA9A53C990148ACE6B5319A5F...   NESSUS
# 1524                                              78008   NESSUS
# 1525                                              87194   NESSUS
#
#                                                   title  \
# 0     Microsoft Internet Explorer Cumulative Securit...
# 1     Microsoft Internet Explorer window() Code Exec...
# 2     Microsoft Internet Explorer Cumulative Securit...
# 3     Cumulative Security Update for Internet Explor...
# 4     Cumulative Security Update for Internet Explor...
# ...                                                 ...
# 1454  Windows Rights Management Services Client with...
# 1455  MBSS-OS-RHEL7-057a - 2.2.1.1 (L1) Ensure time ...
# 1456                               NTP is not installed
# 1524        RHEL 4 / 5 / 6 : JBoss EAP (RHSA-2014:1321)
# 1525                RHEL 6 : JBoss EAP (RHSA-2015:2542)
#
#                                             description plugin_type  is_eol  \
# 0     the cumulative security update for microsoft i...         NaN   False
# 1     a critical vulnerability has been identified i...         NaN   False
# 2     multiple vulnerabilities exist in internet exp...         NaN   False
# 3     multiple vulnerabilities exist in internet exp...         NaN   False
# 4     a remote code execution vulnerability exists i...         NaN   False
# ...                                                 ...         ...     ...
# 1454  \n    \n<p>Rights Management Services (RMS) cl...         NaN   False
# 1455  "MBSS-OS-RHEL7-057a - 2.2.1.1 (L1) Ensure time...         NaN   False
# 1456  "NTP is not installed" : </br></br>The followi...         NaN   False
# 1524  Updated packages for Red Hat JBoss Enterprise ...         NaN   False
# 1525  Updated jboss-ec2-eap packages that fix two se...         NaN   False
#
#                                              clean_desc  predictions
# 0     vendor internet explorer cumulative security u...            1
# 1     vendor internet explorer code execution vulner...            1
# 2     vendor internet explorer cumulative security u...            1
# 3     cumulative security update internet explorer m...            1
# 4     cumulative security update internet explorer m...            1
# ...                                                 ...          ...
# 1454  window right management service client service...            1
# 1455  mb o rhel l ensure time synchronization use ma...            1
# 1456  ntp not instal ntp not instal follow clause no...            1
# 1524  rhel jboss eap rhsa update package red hat jbo...            1
# 1525  rhel jboss eap rhsa update jboss ec eap packag...            1
#
# [685 rows x 8 columns]

# %%
obsolete = data[data['title'].str.contains("Obsolete")]
string_eol = data[data['title'].str.contains("EOL")]

# %%
string_eol
# Out:
#                                         plugin_id  \
# 16                                   QUALYS105138
# 18                                   QUALYS105337
# 19                                   QUALYS105338
# 20                                   QUALYS105339
# 21                                   QUALYS105340
# ...                                           ...
# 1322                                 QUALYS150450
# 1457                                        21272
# 1472  6a66f823-798d-4553-a196-f1bf231628dd-105632
# 1473  6a66f823-798d-4553-a196-f1bf231628dd-105859
# 1474  6a66f823-798d-4553-a196-f1bf231628dd-105793
#
#                                    scanner  \
# 16                                  QUALYS
# 18                                  QUALYS
# 19                                  QUALYS
# 20                                  QUALYS
# 21                                  QUALYS
# ...                                    ...
# 1322                                QUALYS
# 1457                                NESSUS
# 1472  6a66f823-798d-4553-a196-f1bf231628dd
# 1473  6a66f823-798d-4553-a196-f1bf231628dd
# 1474  6a66f823-798d-4553-a196-f1bf231628dd
#
#                                                   title  \
# 16    EOL/Obsolete Hardware: Juniper NetScreen-5GT D...
# 18    EOL/Obsolete Software: Microsoft Office 2000 S...
# 19    EOL/Obsolete Operating System: Microsoft Windo...
# 20    EOL/Obsolete Operating System: Microsoft Windo...
# 21    EOL/Obsolete Operating System: Microsoft Windo...
# ...                                                 ...
# 1322      EOL/Obsolete Software: AngularJS 1.x Detected
# 1457  Slackware 10.0 / 10.1 / 10.2 / current : mozil...
# 1472  EOL/Obsolete Operating System: Microsoft Windo...
# 1473  EOL/Obsolete Operating System: Microsoft Windo...
# 1474  EOL/Obsolete Operating System: Microsoft Windo...
#
#                                             description plugin_type  is_eol  \
# 16    juniper ended support for netscreen-5gt on dec...         NaN    True
# 18    microsoft office 2000 service pack 3 has been ...         NaN    True
# 19    the host is running windows vista with no serv...         NaN    True
# 20    the host is running windows server 2003 with n...         NaN    True
# 21    the host is running windows server 2003 with s...         NaN    True
# ...                                                 ...         ...     ...
# 1322  Web application is using End of Life AngularJS...         NaN    True
# 1457  New Mozilla packages are available for Slackwa...         NaN    True
# 1472                                                            NaN    True
# 1473                                                            NaN    True
# 1474                                                            NaN    True
#
#                                              clean_desc  predictions
# 16    hardware juniper netscreen gt detect juniper e...            1
# 18    software vendor office service pack sp detect ...            1
# 19    operate system vendor windows vista detect hos...            1
# 20    operate system vendor windows server detect ho...            1
# 21    operate system vendor windows server service p...            1
# ...                                                 ...          ...
# 1322  software angularjs x detect web application us...            1
# 1457  slackware current vendor security ssa new vend...            1
# 1472        operate system vendor windows server detect            1
# 1473      operate system vendor windows server r detect            1
# 1474                operate system vendor window detect            1
#
# [735 rows x 8 columns]

# %%
obsolete
# Out:
#                                               plugin_id  \
# 16                                         QUALYS105138
# 18                                         QUALYS105337
# 19                                         QUALYS105338
# 20                                         QUALYS105339
# 21                                         QUALYS105340
# ...                                                 ...
# 1473        6a66f823-798d-4553-a196-f1bf231628dd-105859
# 1474        6a66f823-798d-4553-a196-f1bf231628dd-105793
# 1476  c081eeb9-10f2-4867-bea9-90f5bee5266a-apache-to...
# 1481                               FTP-PROFTPD-OBSOLETE
# 1482                               HTTP-THTTPD-OBSOLETE
#
#                                    scanner  \
# 16                                  QUALYS
# 18                                  QUALYS
# 19                                  QUALYS
# 20                                  QUALYS
# 21                                  QUALYS
# ...                                    ...
# 1473  6a66f823-798d-4553-a196-f1bf231628dd
# 1474  6a66f823-798d-4553-a196-f1bf231628dd
# 1476  c081eeb9-10f2-4867-bea9-90f5bee5266a
# 1481                               NEXPOSE
# 1482                               NEXPOSE
#
#                                                   title  \
# 16    EOL/Obsolete Hardware: Juniper NetScreen-5GT D...
# 18    EOL/Obsolete Software: Microsoft Office 2000 S...
# 19    EOL/Obsolete Operating System: Microsoft Windo...
# 20    EOL/Obsolete Operating System: Microsoft Windo...
# 21    EOL/Obsolete Operating System: Microsoft Windo...
# ...                                                 ...
# 1473  EOL/Obsolete Operating System: Microsoft Windo...
# 1474  EOL/Obsolete Operating System: Microsoft Windo...
# 1476                    Apache Tomcat: Obsolete version
# 1481                      Obsolete ProFTPD installation
# 1482                            THTTPD Obsolete Version
#
#                                             description plugin_type  is_eol  \
# 16    juniper ended support for netscreen-5gt on dec...         NaN    True
# 18    microsoft office 2000 service pack 3 has been ...         NaN    True
# 19    the host is running windows vista with no serv...         NaN    True
# 20    the host is running windows server 2003 with n...         NaN    True
# 21    the host is running windows server 2003 with s...         NaN    True
# ...                                                 ...         ...     ...
# 1473                                                            NaN    True
# 1474                                                            NaN    True
# 1476  Your version of Tomcat is no longer maintained...         NaN    True
# 1481  \n    \n<p>ProFTPD versions prior to 1.3.5 are...         NaN    True
# 1482  \n    \n<p>\n         Versions of THTTPD earli...         NaN    True
#
#                                              clean_desc  predictions
# 16    hardware juniper netscreen gt detect juniper e...            1
# 18    software vendor office service pack sp detect ...            1
# 19    operate system vendor windows vista detect hos...            1
# 20    operate system vendor windows server detect ho...            1
# 21    operate system vendor windows server service p...            1
# ...                                                 ...          ...
# 1473      operate system vendor windows server r detect            1
# 1474                operate system vendor window detect            1
# 1476  vendor tomcat version version of tomcat no lon...            1
# 1481  proftpd installation n n proftpd version prior...            1
# 1482  thttpd version n n n version of thttpd earlier...            1
#
# [740 rows x 8 columns]

# %%
np.mean(obsolete['is_eol'])
# Out:
# 1.0

# %%
np.mean(string_eol['is_eol'])
# Out:
# 1.0
